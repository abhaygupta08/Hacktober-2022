# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-the-Dataset" data-toc-modified-id="Load-the-Dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load the Dataset</a></span></li><li><span><a href="#Compare-by-Means" data-toc-modified-id="Compare-by-Means-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Compare by Means</a></span></li><li><span><a href="#Compare-by-Distplots" data-toc-modified-id="Compare-by-Distplots-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Compare by Distplots</a></span></li><li><span><a href="#Compare-by-Boxplots" data-toc-modified-id="Compare-by-Boxplots-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Compare by Boxplots</a></span></li><li><span><a href="#Compare-by-T-Tests" data-toc-modified-id="Compare-by-T-Tests-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Compare by T-Tests</a></span></li></ul></div>

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import IPython as ip
mpl.style.use('ggplot')
mpl.rc('font', family='Noto Sans CJK TC')
ip.display.set_matplotlib_formats('svg')

# %%
np.random.seed(20180701+3)

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv('dataset_howell1.csv', sep=';')
df.shape  # (rows, columns)
# Out:
# (544, 4)

# %%
group_male = df[df.male == 1].height
group_female = df[df.male == 0].height

# %%
group_male.head()
# Out:
# 0    151.765
# 3    156.845
# 5    163.830
# 7    168.910
# 9    165.100
# Name: height, dtype: float64

# %%
group_female.head()
# Out:
# 1    139.700
# 2    136.525
# 4    145.415
# 6    149.225
# 8    147.955
# Name: height, dtype: float64

# %%
group_ctl = df.sample(30).height
group_exp_1 = df.sample(30).height
group_exp_2 = group_male.sample(30)

# %%
group_ctl.head()
# Out:
# 3      156.845
# 288    151.130
# 292    153.035
# 506    154.940
# 528    160.655
# Name: height, dtype: float64

# %%
group_exp_1.head()
# Out:
# 83     160.9598
# 476    153.6700
# 267    161.2900
# 404    146.0500
# 1      139.7000
# Name: height, dtype: float64

# %%
group_exp_2.head()
# Out:
# 233    165.735
# 72     153.670
# 105    167.005
# 360     71.120
# 139    170.815
# Name: height, dtype: float64

# %% [markdown]
# # Compare by Means

# %%
group_male.describe()
# Out:
# count    257.000000
# mean     142.321037
# std       28.871320
# min       60.452000
# 25%      124.993400
# 50%      157.480000
# 75%      161.925000
# max      179.070000
# Name: height, dtype: float64

# %%
group_female.describe()
# Out:
# count    287.000000
# mean     134.630278
# std       25.930233
# min       53.975000
# 25%      125.247400
# 50%      146.050000
# 75%      151.130000
# max      162.560000
# Name: height, dtype: float64

# %%
group_male.mean() > group_female.mean()
# Out:
# True

# %%
group_ctl.describe()
# Out:
# count     30.000000
# mean     138.504507
# std       22.716142
# min       81.915000
# 25%      126.523750
# 50%      146.685000
# 75%      155.416250
# max      162.560000
# Name: height, dtype: float64

# %%
group_exp_1.describe()
# Out:
# count     30.000000
# mean     142.789487
# std       29.459988
# min       62.230000
# 25%      145.573750
# 50%      152.082500
# 75%      159.702500
# max      172.720000
# Name: height, dtype: float64

# %%
group_exp_2.describe()
# Out:
# count     30.000000
# mean     151.817993
# std       23.247342
# min       71.120000
# 25%      150.336250
# 50%      159.385000
# 75%      163.671250
# max      171.119800
# Name: height, dtype: float64

# %%
group_exp_1.mean() > group_ctl.mean()
# Out:
# True

# %%
group_exp_2.mean() > group_ctl.mean()
# Out:
# True

# %% [markdown]
# # Compare by Distplots

# %%
sns.distplot(group_male)
sns.distplot(group_female)
plt.legend(['Male', 'Female'])

# %%
sns.distplot(group_ctl)
sns.distplot(group_exp_1)
plt.legend(['Control', 'Experimental 1'])

# %%
sns.distplot(group_ctl)
sns.distplot(group_exp_2)
plt.legend(['Control', 'Experimental 2'])

# %% [markdown]
# # Compare by Boxplots

# %%
sns.boxplot(data=[group_male, group_female], notch=True)

# %% [markdown]
# * Box: $Q_1$ to $Q_3$ = 25th to 75th percentile = middle 50% of data.
# * Line: the median = the 50th percentile.
# * Whiskers:
#     * $ Q_1 - 1.5 IQR $, where $ IQR = Q_3 - Q_1 $.
#     * $ Q_3 + 1.5 IQR $.
#     * = middle 99.3% if data follow a normal distribution.
# * Points: out of middle 99.3% if data follow a normal distribution, may be outliers.
# * Notch: $ median \pm 1.57\dfrac{IQR}{\sqrt{n}} $ = 95% confidence interval for the median.
#     * The 95% confidence interval for the median also can be bootstrapped.
#     * The 95% confidence interval also can be “for mean” in other plots.
#     * If the notches don't overlap, may be different significantly.

# %%
sns.boxplot(data=[group_ctl, group_exp_1, group_exp_2], notch=True)

# %% [markdown]
# # Compare by T-Tests

# %%
alpha = 0.05

# %%
r = sp.stats.ttest_ind(group_male, group_female)
print(r)
print(r.pvalue < alpha)
# Out:
# Ttest_indResult(statistic=3.273256851064318, pvalue=0.0011309256622558707)
# True

# %%
r = sp.stats.ttest_ind(group_ctl, group_exp_1)
print(r)
print(r.pvalue < alpha)
# Out:
# Ttest_indResult(statistic=-0.6308917884566415, pvalue=0.5305895984689146)
# False

# %%
r = sp.stats.ttest_ind(group_ctl, group_exp_2)
print(r)
print(r.pvalue < alpha)
# Out:
# Ttest_indResult(statistic=-2.243496972378143, pvalue=0.028698508008071433)
# True
