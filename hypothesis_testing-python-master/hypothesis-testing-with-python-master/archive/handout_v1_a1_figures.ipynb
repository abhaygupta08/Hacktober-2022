# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import IPython as ip
mpl.style.use('ggplot')
mpl.rc('font', family='Noto Sans CJK TC')
ip.display.set_matplotlib_formats('svg')

# %%
alpha_v = np.arange(0.01, 0.1+0.01, 0.01)
beta = 0.2
std_effect_size_v = np.arange(0.1, 0.5+0.05, 0.05)

sample_size_m = np.zeros((len(alpha_v), len(std_effect_size_v)))
for i in range(len(alpha_v)):
    for j in range(len(std_effect_size_v)):
        sample_size_m[i, j] = sm.stats.tt_ind_solve_power(
            alpha=alpha_v[i],
            power=1-beta,
            effect_size=std_effect_size_v[j],
            ratio=1,
            nobs1=None,
        )

plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    sample_size_m,
    vmax=300, vmin=0, cmap='Greens', annot=True, fmt='.0f',
    yticklabels=[f'{a:.2f}' for a in alpha_v],
    xticklabels=[f'{e:.2f}' for e in std_effect_size_v],
    cbar_kws=dict(label='Sample Size'),
)
plt.ylabel(f'α, β = {beta:.2f}')
plt.xlabel('Std Effect Size')
# plt.savefig('outputs/a1_alpha_std_effect_size_sample_size.png', bbox_inches='tight', dpi=600)
# Out:
# Text(0.5, 22.199999999999996, 'Std Effect Size')

# %%
alpha_v = np.arange(0.001, 0.01+0.001, 0.001)
beta = 0.01
std_effect_size_v = np.arange(0.01, 0.1+0.01, 0.01)

sample_size_m = np.zeros((len(alpha_v), len(std_effect_size_v)))
for i in range(len(alpha_v)):
    for j in range(len(std_effect_size_v)):
        sample_size_m[i, j] = sm.stats.tt_ind_solve_power(
            alpha=alpha_v[i],
            power=1-beta,
            effect_size=std_effect_size_v[j],
            ratio=1,
            nobs1=None,
        )

plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    sample_size_m,
    vmax=50000, vmin=0, cmap='Greens', annot=True, fmt='.0f',
    yticklabels=[f'{a:.3f}'[1:] for a in alpha_v],
    xticklabels=[f'{e:.2f}' for e in std_effect_size_v],
    cbar=False,
    # cbar_kws=dict(label='Sample Size'),
)
plt.ylabel(f'α, β = {beta:.2f}')
plt.xlabel('Std Effect Size')
# plt.savefig('outputs/a1_alpha_std_effect_size_sample_size_2.png', bbox_inches='tight', dpi=600)
# Out:
# Text(0.5, 22.199999999999996, 'Std Effect Size')

# %%
# f: alpha, beta=0.20, anr -> inverse_alpha

alpha_v = np.arange(0.1, 0, -0.01)
beta = 0.20
anr_v = np.arange(1, 0.5-0.05, -0.05)

power = 1-beta
apr_v = 1-anr_v

inverse_alpha_m = alpha_v*anr_v[:, None] / (alpha_v*anr_v[:, None] + power*apr_v[:, None])

plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    inverse_alpha_m,
    vmin=0, vmax=1, cmap='Reds', annot=True, fmt='.2f',
    yticklabels=[f'{p:.2f}' for p in anr_v],
    xticklabels=[f'{a:.2f}' for a in alpha_v],
    cbar_kws=dict(label='Inverse α'),
)
plt.ylabel('Actaul Negative Rate')
plt.xlabel(f'α, β = {beta:.2f}')
# plt.savefig('outputs/a1_anr_alpha_inverse_alpha.png', bbox_inches='tight', dpi=600)
# Out:
# Text(0.5, 22.199999999999996, 'α, β = 0.20')

# %%
# f: alpha, beta=0.20, anr -> inverse_alpha

alpha_v = np.arange(0.1, 0, -0.01)
beta = 0.20
anr_v = np.arange(1, 0.9-0.01, -0.01)

power = 1-beta
apr_v = 1-anr_v

inverse_alpha_m = alpha_v*anr_v[:, None] / (alpha_v*anr_v[:, None] + power*apr_v[:, None])

plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    inverse_alpha_m,
    vmin=0, vmax=1, cmap='Reds', annot=True, fmt='.2f',
    yticklabels=[f'{p:.2f}' for p in anr_v],
    xticklabels=[f'{a:.2f}' for a in alpha_v],
    cbar_kws=dict(label='Inverse α'),
)
plt.ylabel('Actaul Negative Rate')
plt.xlabel(f'α, β = {beta:.2f}')
# plt.savefig('outputs/a1_anr_alpha_inverse_alpha_3.png', bbox_inches='tight', dpi=600)
# Out:
# Text(0.5, 22.199999999999996, 'α, β = 0.20')

# %%
# f: alpha, beta=0.01, anr -> inverse_alpha

alpha_v = np.arange(0.01, 0, -0.001)
beta = 0.01
anr_v = np.arange(1, 0.9-0.01, -0.01)

power = 1-beta
apr_v = 1-anr_v

inverse_alpha_m = alpha_v*anr_v[:, None] / (alpha_v*anr_v[:, None] + power*apr_v[:, None])

plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    inverse_alpha_m,
    vmin=0, vmax=1, cmap='Reds', annot=True, fmt='.2f',
    yticklabels=[f'{p:.2f}' for p in anr_v],
    xticklabels=[f'{a:.3f}' for a in alpha_v],
    cbar_kws=dict(label='Inverse α'),
)
plt.ylabel('Actaul Negative Rate')
plt.xlabel(f'α, β = {beta:.2f}')
# plt.savefig('outputs/a1_anr_alpha_inverse_alpha_2.png', bbox_inches='tight', dpi=600)
# Out:
# Text(0.5, 22.199999999999996, 'α, β = 0.01')

# %%
# f: alpha=0.05, beta, anr -> for

alpha = 0.05
beta_v = np.arange(0.2, 0, -0.02)
anr_v = np.arange(0.5, 0-0.05, -0.05)

cl = 1-alpha
apr_v = 1-anr_v

inverse_beta_m = beta_v*apr_v[:, None] / (cl*anr_v[:, None] + beta_v*apr_v[:, None])

plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    inverse_beta_m,
    vmin=0, vmax=1, cmap='Blues', annot=True, fmt='.2f',
    yticklabels=[f'{p:.2f}' for p in anr_v],
    xticklabels=[f'{b:.2f}' for b in beta_v],
    cbar_kws=dict(label='Inverse β'),
)
plt.ylabel('Actaul Negative Rate')
plt.xlabel(f'α = {alpha:.2f}, β')
# plt.savefig('outputs/a1_anr_beta_inverse_beta.png', bbox_inches='tight', dpi=600)
# Out:
# Text(0.5, 22.199999999999996, 'α = 0.05, β')

# %%
fair_df = sm.datasets.fair.load_pandas().data
plt.figure(figsize=(6*1.2, 4*1.2))
sns.heatmap(
    np.corrcoef(fair_df.T),
    center=0,
    yticklabels=fair_df.columns,
    xticklabels=fair_df.columns,
    cbar_kws=dict(label="Pearson's r"),
)
# plt.savefig('outputs/a1_fair_r.png', bbox_inches='tight', dpi=600)

# %%
fair_df = sm.datasets.fair.load_pandas().data
ols_res = smf.ols('children ~ yrs_married', fair_df).fit()
ols_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               children   R-squared:                       0.597
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     9437.
# Date:                Sat, 30 Mar 2019   Prob (F-statistic):               0.00
# Time:                        18:41:46   Log-Likelihood:                -8430.3
# No. Observations:                6366   AIC:                         1.686e+04
# Df Residuals:                    6364   BIC:                         1.688e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0259      0.018      1.429      0.153      -0.010       0.062
# ...
